# %% [markdown]
# ![KMEANS.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# [link text](https://stackoverflow.com/questions/34113790/k-means-clustering-using-sklearn-cluster)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
X1 = np.array([[1.713,1.586],[0.18,1.786],[0.353,1.24],[0.94,1.566],[1.486,0.759],[1.266,1.106],[1.54,0.419],[0.459,1.799],[0.773,0.186],[0.906,0.606]])
print(x)

# %%
# https://github.com/vince-lynch/Machine-Learning-KMeans-Celeb-HeightWeight/blob/master/k-means-clustering-using-sklearn-cluster.ipynb

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

from sklearn.cluster import KMeans
X1 = np.array([[1.713,1.586],[0.18,1.786],[0.353,1.24],[0.94,1.566],[1.486,0.759],[1.266,1.106],[1.54,0.419],[0.459,1.799],[0.773,0.186],[0.906,0.606]])
#print(x)

#X = np.array([[1,2],[5,8],[1.5,1.8],[1,0.6],[9,11]])

kmeans = KMeans(n_clusters=3)
kmeans.fit(X1)

centroid = kmeans.cluster_centers_
labels = kmeans.labels_

print (centroid)
print(labels)

colors = ["g.","r.","c."]

for i in range(len(X1)):
   print ("coordinate:" , X1[i], "label:", labels[i])
   plt.plot(X1[i][0],X1[i][1],colors[labels[i]],markersize=20)

plt.scatter(centroid[:,0],centroid[:,1], marker = "x", s=200, linewidths = 5, zorder =20)

plt.show()

# %% [markdown]
# [link text](https://www.kaggle.com/tonzowonzo/simple-k-means-clustering-on-the-iris-dataset)

# %% [markdown]
# [link text](http://users.sussex.ac.uk/~christ/crs/ml/lab-exercises.html)

# %% [markdown]
# [link text](https://jakevdp.github.io/PythonDataScienceHandbook/05.11-k-means.html)

# %%
#https://medium.com/@dilekamadushan/introduction-to-k-means-clustering-7c0ebc997e00

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
dataset = pd.read_csv('/content/kmeans.csv')
x = dataset.iloc[:, [1, 2]].values

# %%
x1  = x[:,0]
y1 = x[:,1]
print(y1)

plt.title('class')
plt.xlabel('var1')
plt.ylabel('var2')

plt.scatter(x1, y1)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

from sklearn.cluster import KMeans

nData = x[:,:2]
#np.append(nData, [158,64])

newArr = nData

print(newArr)

# %%
X = newArr

#X.reshape(-1, 1)

kmeans = KMeans(n_clusters=3)
kmeans.fit(X)

centroid = kmeans.cluster_centers_
labels = kmeans.labels_

print (centroid)
print(labels)

colors = ["g.","r.","c."]

for i in range(len(X)):
   print ("coordinate:" , X[i], "label:", labels[i])
   plt.plot(X[i][0],X[i][1],colors[labels[i]],markersize=10)

plt.scatter(centroid[:,0],centroid[:,1], marker = "x", s=150, linewidths = 5, zorder =10)

plt.show()

# %%
import pandas as pd

df = pd.DataFrame(x)
#add the labels column [boy/girl]
#print(df)
df[4] = labels
#df[3].replace(['girl', 'boy'], [1,0]) 
df[4].replace({0: 'Boy', 1: 'Girl'}, inplace=True)

df.columns = ['var1', 'var2', 'class']

df.set_index('class', inplace=True)

print(df)

#CelebDF = df

# %%
kmean=KMeans(n_clusters=3)
kmean.fit(x)

# %%
y_kmeans = kmeans.fit_predict(x)

# %%
#Visualising the clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'red', label = '0')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 100, c = 'blue', label = '1')
#Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'yellow', label = 'Centroids')

plt.legend()

# %%
#importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#importing the Iris dataset with pandas
dataset = pd.read_csv('/content/Iris.csv')
x = dataset.iloc[:, [1, 2, 3, 4]].values

# %%
from sklearn.cluster import KMeans
#Applying kmeans to the dataset / Creating the kmeans classifier
kmeans = KMeans(n_clusters = 3, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

# %%
#Visualising the clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Iris-virginica')

#Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'yellow', label = 'Centroids')

plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt


from sklearn.cluster import KMeans

X = np.array([[1,2],[5,8],[1.5,1.8],[1,0.6],[9,11]])

kmeans = KMeans(n_clusters=3)
kmeans.fit(X)

centroid = kmeans.cluster_centers_
labels = kmeans.labels_

print (centroid)
print(labels)

colors = ["g.","r.","c."]

for i in range(len(X)):
   print ("coordinate:" , X[i], "label:", labels[i])
   plt.plot(X[i][0],X[i][1],colors[labels[i]],markersize=10)

plt.scatter(centroid[:,0],centroid[:,1], marker = "x", s=150, linewidths = 5, zorder =10)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

from sklearn.cluster import KMeans
X1 = np.array([[1.713,1.586],[0.18,1.786],[0.353,1.24],[0.94,1.566],[1.486,0.759],[1.266,1.106],[1.54,0.419],[0.459,1.799],[0.773,0.186]])
X2 = np.array([[0.906,0.606]]

#X = np.array([[1,2],[5,8],[1.5,1.8],[1,0.6],[9,11]])

kmeans = KMeans(n_clusters=3)
kmeans.fit(X1)
kmeans.predict(X2)

centroid = kmeans.cluster_centers_
labels = kmeans.labels_

print (centroid)
print(labels)

colors = ["g.","r.","c."]

for i in range(len(X1)):
   print ("coordinate:" , X1[i], "label:", labels[i])
   plt.plot(X1[i][0],X1[i][1],colors[labels[i]],markersize=20)

plt.scatter(centroid[:,0],centroid[:,1], marker = "x", s=200, linewidths = 5, zorder =20)

plt.show()

# %%
# transform to dataframe
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

X = np.array([[1.713,1.586],[0.18,1.786],[0.353,1.24],[0.94,1.566],[1.486,0.759],[1.266,1.106],[1.54,0.419],[0.459,1.799],[0.773,0.186],[0.906,0.606]])
df = pd.DataFrame(X)
df.columns = ["var1", "var2"]
#df["cluster"] = predict
colors = sns.color_palette()[0:4]
#df = df.sort_values("cluster")

# check plot
sns.scatterplot(df["var1"], df["var2"], palette=colors)
plt.show()

# define rename schema
mynames = {"0": "center_left", "1": "top_left", "2": "bot_right", "3": "center"}
#df["cluster_name"] = [mynames[str(i)] for i in df.cluster]

# plot again to verify order
sns.scatterplot(df["var1"], df["var2"],palette=colors)
sns.despine()
plt.show()

# save dataframe as CSV
#df.to_csv("myoutput.csv")

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

from sklearn.cluster import KMeans
X2= np.array([[1.713,1.586],[0.18,1.786],[0.353,1.24],[0.94,1.566],[1.486,0.759],[1.266,1.106],[1.54,0.419],[0.459,1.799],[0.773,0.186],[0.906,0.606]])
print(X2)
kmeans = KMeans(n_clusters=3,random_state=2)
kmeans.fit(X2)

centroid = kmeans.cluster_centers_
labels = kmeans.labels_

print(centroid)
print(labels)

colors = ["g.","r.","c."]

for i in range(len(X2)):
   print ("coordinate:" , X2[i], "label:", labels[i])
   plt.plot(X2[i][0],X2[i][1],colors[labels[i]],markersize=20)

plt.scatter(centroid[:,0],centroid[:,1], marker = "x", s=200, linewidths = 5, zorder =20)

plt.show()
# Out:
# [[1.713 1.586]
#  [0.18  1.786]
#  [0.353 1.24 ]
#  [0.94  1.566]
#  [1.486 0.759]
#  [1.266 1.106]
#  [1.54  0.419]
#  [0.459 1.799]
#  [0.773 0.186]
#  [0.906 0.606]]
# [[1.30633333 1.41933333]
#  [1.17625    0.4925    ]
#  [0.33066667 1.60833333]]
# [0 2 2 0 1 0 1 2 1 1]
# coordinate: [1.713 1.586] label: 0
# coordinate: [0.18  1.786] label: 2
# coordinate: [0.353 1.24 ] label: 2
# coordinate: [0.94  1.566] label: 0
# coordinate: [1.486 0.759] label: 1
# coordinate: [1.266 1.106] label: 0
# coordinate: [1.54  0.419] label: 1
# coordinate: [0.459 1.799] label: 2
# coordinate: [0.773 0.186] label: 1
# coordinate: [0.906 0.606] label: 1
